# %%
import os
import shutil
import re 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
import cv2

# %%
# first copying one sample image from every folder to a single folder
img_folders = os.listdir('train')
base_path = "train/"

for img_folder in img_folders:
    img_folder_path = base_path + img_folder + '/'
    img_list = os.listdir(img_folder_path)
    file = img_list[1]
    img_path = img_folder_path + file
    shutil.copy2(img_path, 'collage_sample/{}'.format(file))
# Out:
# 'collage_sample/arm10471.png'
# 'collage_sample/belt23373.png'
# 'collage_sample/crown7539.png'
# 'collage_sample/boomerang28552.png'
# 'collage_sample/penguin41574.png'
# 'collage_sample/pencil27724.png'
# 'collage_sample/42696.png'
# 'collage_sample/moon30183.png'
# 'collage_sample/brain19863.png'
# 'collage_sample/snowman1335.png'
# 'collage_sample/sea_turtle30727.png'
# 'collage_sample/car37664.png'
# 'collage_sample/58483.png'
# 'collage_sample/diamond338.png'
# 'collage_sample/hand25282.png'
# 'collage_sample/book3953.png'
# 'collage_sample/dolphin21795.png'
# 'collage_sample/59136.png'
# 'collage_sample/28705.png'
# 'collage_sample/eye24102.png'
# 'collage_sample/bridge1921.png'
# 'collage_sample/cow13811.png'
# 'collage_sample/t-shirt48143.png'
# 'collage_sample/lightning30453.png'
# 'collage_sample/crab42492.png'
# 'collage_sample/donut49561.png'
# 'collage_sample/radio4828.png'
# 'collage_sample/star25665.png'
# 'collage_sample/45975.png'
# 'collage_sample/house4974.png'
# ...

# %%
file_list = os.listdir('collage_sample')

images = []
for file in file_list:
    img = cv2.imread('collage_sample/' + file)
    res = cv2.resize(img, dsize=(28,28))
    res = np.invert(res)
    images.append(res)

fig = plt.figure(1, (30, 30))
grid = ImageGrid(fig, 110,
                 nrows_ncols=(10, 9),
                 axes_pad=.5,
)



clean_file_list = [re.sub('[0-9]+.png', '', s) for s in file_list]

for i in range(len(images) + 1):
    try: # to get rid of empty subplot on bottom right
        grid[i].imshow(images[i])
        grid[i].set_title(clean_file_list[i], size = 25)
    except:pass
    
    grid[i].axis('off')


plt.show(block=True);

fig.savefig('collage_sample.jpg');
